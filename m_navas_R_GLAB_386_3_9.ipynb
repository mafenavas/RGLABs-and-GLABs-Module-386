# %% [markdown]
# <a href="https://colab.research.google.com/github/mafenavas/RGLABs-and-GLABs-Module-386/blob/main/m_navas_R_GLAB_386_3_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Guided Lab - 386.3.9 - Adding new column to existing DataFrame in Pandas**
#
#
# ##**Lab Overview:**
# <font color="red">**Note: This is a mandatory lab and will be graded. The instructor will walk through the lab during class. Learners must complete and submit it.**</font>
#
# In this lab, you will explore different techniques for adding new columns to an existing Pandas DataFrame. You will work with a dataset to create new columns using constant values, calculations, conditional logic, and data from external sources.
#
# Through hands-on practice, you will learn how to transform and enrich datasets by deriving new information from existing data. These skills are essential for data analysis, reporting, and real-world data manipulation tasks.
#
# ##**Learning Objectives:**
#
# - By the end of this lab, learners will be able to add new columns to Panda Dataframe using several approaches.
#
#
# ## **Introduction:**
# In Pandas, a DataFrame represents a two-dimensional, heterogenous, tabular data structure with labeled rows and columns (axes). In simple words, it contains three components ― data, rows, columns.
#
# Let's discuss how to add new columns to the existing DataFrame in Pandas. There are multiple ways we can do this task.
#
# ## **Instructions**

# %% [markdown]
# ## **Method #1: By using Dictionary and declaring a new list as a column.**
#
# **Example 1.1:**
#
# Note that the length of your list should match the length of the index column; otherwise, it will show an error.

# %%
# in this program we will add a new column to the dataframe
import pandas as pd
# Define a dictionary containing Students data and their respective details
data = {'Name': ['Jane', 'Princi', 'James', 'Fadi'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc'],
        'Score 1' : [56,86,77,45],
        'Score 2' : [50,96,60,30]}

# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
print("------before  adding column -------")
print(df)


# Declare a list that is to be converted into a column
address = ['NYC', 'NJ', 'CA', 'PA']

# adding a address column to the dataframe
df['Address'] = address
print("------after -------")
# Observe the result
print(df)
# in this program the address column is added in hte last position
# Out:
# ------before  adding column -------
#      Name  Height Qualification  Score 1  Score 2
# 0    Jane     5.1           Msc       56       50
# 1  Princi     6.2            MA       86       96
# 2   James     5.1           Msc       77       60
# 3    Fadi     5.2           Msc       45       30
# ------after -------
#      Name  Height Qualification  Score 1  Score 2 Address
# 0    Jane     5.1           Msc       56       50     NYC
# 1  Princi     6.2            MA       86       96      NJ
# 2   James     5.1           Msc       77       60      CA
# 3    Fadi     5.2           Msc       45       30      PA

# %% [markdown]
# **Example: 1.2**
#
# - You can apply basic arithmetic operations such as addition, subtraction, multiplication, and division to Pandas DataFrame objects the same way you would with NumPy arrays:
#
# - The below example adds a new column based on a calculation of the existing column.

# %%
# defining a dictionary containing Students data and their respective details
data = {'Name': ['Jane', 'Princi', 'James', 'Fadi'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc'],
        'Score 1' : [56,86,77,45],
        'Score 2' : [50,96,60,30]}

# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
print("------before -------")
print(df)
print("------after adding column -------")
df['Total_Score'] = df['Score 1'] +  df['Score 2']

print(df)
# Out:
# ------before -------
#      Name  Height Qualification  Score 1  Score 2
# 0    Jane     5.1           Msc       56       50
# 1  Princi     6.2            MA       86       96
# 2   James     5.1           Msc       77       60
# 3    Fadi     5.2           Msc       45       30
# ------after adding column -------
#      Name  Height Qualification  Score 1  Score 2  Total_Score
# 0    Jane     5.1           Msc       56       50          106
# 1  Princi     6.2            MA       86       96          182
# 2   James     5.1           Msc       77       60          137
# 3    Fadi     5.2           Msc       45       30           75

# %% [markdown]
# **Example: 1.3**

# %%
data = {'Name': ['Jane', 'Princi', 'James', 'Fadi'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc'],
        'Score 1' : [56,86,77,45],
        'Score 2' : [50,96,60,30]}

# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
print("------before -------")
print(df)
print("------after adding column -------")
#
df['Total_Score'] = df['Score 1'] +  df['Score 2']
df['Total_Score_average'] = df['Total_Score']/ 2
print(df)
df
# Out:
# ------before -------
#      Name  Height Qualification  Score 1  Score 2
# 0    Jane     5.1           Msc       56       50
# 1  Princi     6.2            MA       86       96
# 2   James     5.1           Msc       77       60
# 3    Fadi     5.2           Msc       45       30
# ------after adding column -------
#      Name  Height Qualification  Score 1  Score 2  Total_Score  \
# 0    Jane     5.1           Msc       56       50          106
# 1  Princi     6.2            MA       86       96          182
# 2   James     5.1           Msc       77       60          137
# 3    Fadi     5.2           Msc       45       30           75
#
#    Total_Score_average
# 0                 53.0
# 1                 91.0
# 2                 68.5
# 3                 37.5
#      Name  Height Qualification  Score 1  Score 2  Total_Score  \
# 0    Jane     5.1           Msc       56       50          106
# 1  Princi     6.2            MA       86       96          182
# ...

# %% [markdown]
# **Example: 1.4**
#
# In the below example, we will rearrange columns and skip the height column.

# %%
data = {'Name': ['Jane', 'Princi', 'James', 'Fadi'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc'],
       'Score 1' : [56,86,77,45],
       'Score 2' : [50,96,60,30]
       }

# Convert the dictionary into DataFrame
df = pd.DataFrame(data,columns = ['Score 1','Score 2','Name', 'Qualification'  ])
print("------before -------")
print(df)
print("------after adding column -------")

df['Total_Score'] = df['Score 1'] +  df['Score 2']
print(df)
# Out:
# ------before -------
#    Score 1  Score 2    Name Qualification
# 0       56       50    Jane           Msc
# 1       86       96  Princi            MA
# 2       77       60   James           Msc
# 3       45       30    Fadi           Msc
# ------after adding column -------
#    Score 1  Score 2    Name Qualification  Total_Score
# 0       56       50    Jane           Msc          106
# 1       86       96  Princi            MA          182
# 2       77       60   James           Msc          137
# 3       45       30    Fadi           Msc           75

# %% [markdown]
# **Example 1.5**
#
# In this example, we will construct a Pandas DataFrame from a nested list and perform vectorized calculations to derive a new "Percentage" column. This demonstrates how to transform raw data into a structured format and apply mathematical operations across an entire dataset simultaneously.

# %%
# importing pandas library
import pandas as pd

# creating and initializing a list
values = [['Rohan', 455], ['Elvish', 250], ['John', 495],
          ['Sai', 400], ['Eric', 350], ['Adam', 450]]

# creating a pandas dataframe
df = pd.DataFrame(values, columns=['Name', 'Univ_Marks'])

# displaying the data frame

print('Data frame before calculating percentage\n')
print(df)
print('\nData frame with Percentage Column\n')

# Creating new column Percentage derived from Univ_Marks
df["Percentage"] = df["Univ_Marks"]/500*100

# displaying the data frame
print(df)
# Out:
# Data frame before calculating percentage
#
#      Name  Univ_Marks
# 0   Rohan         455
# 1  Elvish         250
# 2    John         495
# 3     Sai         400
# 4    Eric         350
# 5    Adam         450
#
# Data frame with Percentage Column
#
#      Name  Univ_Marks  Percentage
# 0   Rohan         455        91.0
# 1  Elvish         250        50.0
# 2    John         495        99.0
# 3     Sai         400        80.0
# 4    Eric         350        70.0
# 5    Adam         450        90.0

# %% [markdown]
# ## **Method #2: By using DataFrame.insert() function**
#
# It gives the freedom to add a column at any position we like, and not just at the end. It also provides different options for inserting the column values.
# - **Modifies In-Place:** insert() modifies the DataFrame in place. It does not return a new DataFrame; it directly changes the existing one.
#
# - **One Column at a Time:** insert() is designed to add a single column at a time. You cannot add multiple columns in a single insert() call.
# - **No Direct Chaining: **Due to its in-place modification, insert() is not typically used for method chaining in the same way assign() is.
# - **Handles Duplicates:** It raises a ValueError if the column name already exists, unless allow_duplicates=True is set (which is generally not recommended for clarity).
#
# ## **When to use insert():**
#
# - When you need to insert a column at a specific position (e.g., at the beginning or in the middle of existing columns).
# - When you want to modify the original DataFrame directly and don't need a new copy.
# - When you are adding a single column.
#
#
# **Example 2.1**
#
# In this example, we will convert a Python dictionary into a Pandas DataFrame and utilize the insert() method to add a new "Age" column at a specific index. This highlights how to structure labeled datasets and precisely control the placement of new data within an existing table.

# %%
# Import pandas package
import pandas as pd

# Define a dictionary containing Students data
data = {'Name': ['Jane', 'Princi', 'James', 'Fadi'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc'],
       'Score 1' : [56,86,77,45],
           'Score 2' : [50,96,60,30]}

# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
print("------before -------")
print(df)
# Using DataFrame.insert() adding age column
df.insert(2, "Age", [21, 23, 24, 21], True)
print("------after adding column -------")
# Observe the result
print(df)
# Out:
# ------before -------
#      Name  Height Qualification  Score 1  Score 2
# 0    Jane     5.1           Msc       56       50
# 1  Princi     6.2            MA       86       96
# 2   James     5.1           Msc       77       60
# 3    Fadi     5.2           Msc       45       30
# ------after adding column -------
#      Name  Height  Age Qualification  Score 1  Score 2
# 0    Jane     5.1   21           Msc       56       50
# 1  Princi     6.2   23            MA       86       96
# 2   James     5.1   24           Msc       77       60
# 3    Fadi     5.2   21           Msc       45       30

# %% [markdown]
# ## **Method #3: Using Dataframe.assign() function**
#
# **Example 3.1**
#
#
# - **Returns a New DataFrame (Non-Inplace):** The assign() method returns a new DataFrame with the new column(s) added. It does not modify the original DataFrame in place. If you want to keep the changes, you must assign the result back to a variable (e.g., df = df.assign(...)).
# - **Method Chaining:** Because it returns a new DataFrame, assign() is excellent for method chaining. You can create multiple new columns or perform other DataFrame operations in a single, readable line.
# - **Creating Multiple Columns:** You can create multiple new columns simultaneously by passing multiple keyword arguments to assign().
# Referencing Other New Columns: In Python 3.6 and later, you can reference newly created or modified columns within the same assign() call. This allows for dependencies between the new columns.
# - **Using Callables (Lambda Functions):** assign() often uses lambda functions (or other callables) to define the new column's values based on existing columns in the DataFrame. This makes it very flexible for calculated columns.
#
# ## **When to use assign():**
# - When you want to create a new DataFrame without modifying the original.
# - When you are doing a series of transformations and want to use method chaining for readability.
# - When you need to create multiple new columns at once.
# - When the new column's values are derived from existing columns through calculations or logic.

# %%
# Import pandas package
import pandas as pd

# Define a dictionary containing Students data
data = {'Name': ['Jane', 'Princi', 'James', 'Fadi'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc'],
       'Score 1' : [56,86,77,45],
           'Score 2' : [50,96,60,30]}

print("------before -------")

# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
print(df)
print("------after adding column -------")
# using DataFrame.assign() method adding 'Address' as the column name and equating it to the list

df = df.assign(address = ['NYC', 'NJ', 'CA', 'PA'])

# Observe the result
print(df)
# Out:
# ------before -------
#      Name  Height Qualification  Score 1  Score 2
# 0    Jane     5.1           Msc       56       50
# 1  Princi     6.2            MA       86       96
# 2   James     5.1           Msc       77       60
# 3    Fadi     5.2           Msc       45       30
# ------after adding column -------
#      Name  Height Qualification  Score 1  Score 2 address
# 0    Jane     5.1           Msc       56       50     NYC
# 1  Princi     6.2            MA       86       96      NJ
# 2   James     5.1           Msc       77       60      CA
# 3    Fadi     5.2           Msc       45       30      PA

# %% [markdown]
# ##**Submission**
# - Submit your completed lab using the Start Assignment button on the assignment page in Canvas.
# - Your submission can be include:
#   - if you are using notebook then, all tasks should be written and submitted in a single notebook file, for example: (**your_name_labname.ipynb**).
#   - if you are using python script file, all tasks should be written and submitted in a single python script file for example: **(your_name_labname.py)**.
# - Add appropriate comments and any additional instructions if required.
